# %% [markdown]
# ## Импорты

# %%
import numpy as np
import matplotlib.pyplot as plt

import os

from PIL import Image

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import geopandas as gpd
from shapely.geometry import Polygon, Point, MultiPolygon
from shapely.ops import cascaded_union
import contextily as cx

from eolearn.core import EOPatch, FeatureType
import geoviews as gv
# Out:
# C:\Users\femt0\miniforge3\envs\eol\lib\site-packages\holoviews\operation\datashader.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Callable

# %% [markdown]
# ## Константы

# %%
data_folder = 'datasets/sentinel2-l2a/64x64-10/'

# %% [markdown]
# ## Соберём существующие точки:

# %% [markdown]
# Функция для координат:

# %%
def PointByCoords(row):
    lon = row['longitude']
    lat = row['latitude']
    if lon <= 62.5:
        lon, lat = lat, lon
    return Point(lon, lat)

# %% [markdown]
# Очистим файл:

# %%
reestr = pd.read_excel('datasets/Reestr-ZZ-na-18.05.2021.xlsx')

# %%
reestr = reestr[['Вид приоритетного загрязняющего вещества',
                 'Регистрационный номер загрязненного участка в Реестре',
                 'Местоположение загрязненного участка',
                 'Административный район',
                 'Координаты загрязненного участка (в географической системе координат)',
                 'Unnamed: 12',
                 'Категория земель до загрязнения',
                 'Площадь загрязненного участка, га',
                 'Уровень загрязнения почв и земель нефтью,  нефтепродуктами, мг/кг ',
                 'Уровень содержания нефти, нефтепродуктов в донных отложениях водных объектов, мг/кг;  уровень содержания нефти, нефтепродуктов в поверхностных водах, мг/куб.дм',
                 'Дата факта последнего разлива']].dropna()

# %%
reestr.rename(columns={
    'Вид приоритетного загрязняющего вещества': 'pollutant_type',
    'Регистрационный номер загрязненного участка в Реестре': 'reg_num',
    'Местоположение загрязненного участка': 'location',
    'Административный район': 'adm_region',
    'Координаты загрязненного участка (в географической системе координат)': 'longitude',
    'Unnamed: 12': 'latitude',
    'Категория земель до загрязнения': 'land_category',
    'Площадь загрязненного участка, га': 'pol_area',
    'Уровень загрязнения почв и земель нефтью,  нефтепродуктами, мг/кг ': 'pol_lvl',
    'Уровень содержания нефти, нефтепродуктов в донных отложениях водных объектов, мг/кг;  уровень содержания нефти, нефтепродуктов в поверхностных водах, мг/куб.дм':
    'oil_lvl',
    'Дата факта последнего разлива': 'spill_date'
}, inplace=True)

# %%
def preprocess(longitude):
  if type(longitude) is float:
    result = float(longitude)
  else:
    result = longitude.replace('°', ' ').replace("'", " ").replace('"', '').replace(',', '.').replace('´', '') \
                      .replace('  ', ' ').replace('ʹ', '').replace('ʹʹ', '').replace('E', '').replace('N', '') \
                      .replace('\\', '').replace('⁰', '.').replace('ʺ', '').replace('\n', '').replace('"', '') \
                      .replace('  ', ' ').replace('˚', '').replace('/', '').replace('*', '') \
                      .replace('’', '').strip(' ').split(' ')
  return result

def to_decimal(longitude):
  if type(longitude) is list:
    if len(longitude) == 3:
      degree = int(longitude[0])
      minute = int(longitude[1]) / 60
      second = float(longitude[2]) / 3600 
      result = degree + minute + second
    else:
      result = longitude[0]
  else:
    result = longitude
  return result

# %%
reestr['longitude'] = reestr.longitude.apply(lambda x: preprocess(x))
reestr['longitude'] = reestr.longitude.apply(lambda x: to_decimal(x))
reestr['latitude'] = reestr.latitude.apply(lambda x: preprocess(x))
reestr['latitude'] = reestr.latitude.apply(lambda x: to_decimal(x))

reestr['longitude'] = reestr['longitude'].astype('float')
reestr['latitude'] = reestr['latitude'].astype('float')

reestr.to_csv('clear.csv')
clear_data = reestr.reset_index(drop=True).drop('spill_date', axis=1)

#del reestr

# %%
display(clear_data.latitude.sort_values(ascending=False).head(4))
display(clear_data.longitude.sort_values(ascending=False).head(4))
# Out:
# 11585    6111.000000
# 10986      80.246084
# 10985      80.208797
# 10988      80.186910
# Name: latitude, dtype: float64
# 11585    7934.000000
# 11049     182.895556
# 10973      80.208239
# 10969      80.185167
# Name: longitude, dtype: float64

# %%
clear_data.drop([11585, 11049, 11568], axis=0, inplace=True)

# %%
clear_data['geometry'] = clear_data.apply(PointByCoords, axis=1)

clear_gdf = gpd.GeoDataFrame(
    clear_data, geometry=clear_data.geometry,
    crs="EPSG:4326")  #.to_crs(epsg=32637) CRS для метров
# Out:
# C:\Users\femt0\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py:121: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %% [markdown]
# d = {'reg_num': ['ПП-2020-2'], 'geometry': [eopatch[FeatureType.BBOX].geometry]}
#
# gdf = gpd.GeoDataFrame(d, crs="EPSG:4326")

# %%
ax = clear_gdf.plot(figsize=(17,17),
                    color='black',
                    marker='x',
                    alpha=0.05)
cx.add_basemap(ax, crs=clear_gdf.crs, source=cx.providers.OpenStreetMap.Mapnik)

#clear_gdf.explore()

# %% [markdown]
# ### Экспорт

# %%
#clear_gdf.to_file('dataframe.shp')
clear_gdf.sort_values(by='pol_area', ascending=False).head(50).to_file('top50.geojson', driver='GeoJSON')

# %% [markdown]
# ## Попробуем вычленить нормальные записи:

# %%
test_data = reestr.reset_index(drop=True).copy()

out = test_data['spill_date'].value_counts().head(11).index.to_list()

test_data = test_data[~test_data['spill_date'].isin(out)]

test_data.loc[test_data['spill_date'] == '29.03.2017', 'spill_date'] = pd.to_datetime('29.03.2017')
test_data.loc[
    test_data["spill_date"].apply(type) == int, 'spill_date'] = pd.to_datetime(test_data[(test_data["spill_date"].apply(type) == int)]['spill_date'], format='%Y')

# %%
# Удалим строки
test_data = test_data[~(test_data["spill_date"].apply(type) == str)]

#Окончательно прогоним, получив даты, и выделим год и месяц
test_data['spill_date'] = pd.to_datetime(test_data['spill_date'])
test_data['spill_year'] = test_data['spill_date'].dt.year
test_data['spill_mnth'] = test_data['spill_date'].dt.month

# %% [markdown]
# ### Оставим только все данные моложе 2017 года, и с площадью разлива более 0,01 га (более 100 кв. м.)

# %%
good_data = test_data[(test_data['spill_year'] >= 2017) & (test_data['pol_area'] >= 0.01)].drop(columns='spill_date')

# %%
good_data
# Out:
#              pollutant_type         reg_num  \
# 3                     нефть   ЛУК-КГ-2020-1
# 17                    нефть  ЛУК-КГ-2020-15
# 20     Нефть, нефтепродукты       ЮС-2018-1
# 21     Нефть, нефтепродукты       ЮС-2018-2
# 23     Нефть, нефтепродукты       ЮС-2018-4
# ...                     ...             ...
# 11731                 нефть       ПП-2019-2
# 11732                 нефть       ПП-2019-3
# 11733                 нефть       ПП-2019-4
# 11734                 нефть       ПП-2020-1
# 11740                 нефть         ТС-2019
#
#                                                 location       adm_region  \
# 3                                   "т.п.3-т.вр.1" Ц-6 Т       Сургутский
# 17                              "т.вр.39-т.вр22" Ц-6           Сургутский
# 20                              район пункта нефтеналива  Нижневартовский
# 21                                    р-он площадки Р-21  Нижневартовский
# 23                                р-он площадки скв.№ 34  Нижневартовский
# ...                                                  ...              ...
# 11731  т.вр.н/с к.54-т. вр. в н/с к.42 (200 метров в ...  Нижневартовский
# 11732  н/пр. к.41- вр. в н/с к.42Б                (47...  Нижневартовский
# 11733  т.вр. к.70В- вр. в н/с к.83В                 (...  Нижневартовский
# 11734  «н/с от т.А. (зад. № 334)-вр.в уз.задв. ЦПС (з...  Нижневартовский
# 11740  Нижневартовский р-н, 30 км до г.Лангепас, 400 ...  Нижневартовский
#
#        longitude   latitude                             land_category  \
# 3      73.547472  62.557611                       земли лесного фонда
# 17     74.803611  62.355556                       земли лесного фонда
# 20     76.121283  62.083820                       земли лесного фонда
# 21     76.121874  62.084043                       земли лесного фонда
# 23     76.120363  62.083883                       земли лесного фонда
# ...          ...        ...                                       ...
# 11731  77.792639  61.173361                       земли лесного фонда
# 11732  77.779139  61.174167                       земли лесного фонда
# 11733  77.738583  61.227111                       земли лесного фонда
# 11734  77.742538  61.162481                       земли лесного фонда
# 11740  75.120758  61.429492  земли лесного фонда/земли иных категорий
#
#        pol_area       pol_lvl oil_lvl  spill_year  spill_mnth
# 3        0.0100       48300,0     нет        2019           1
# 17       0.3000       40600,0     нет        2019           1
# 20       0.0726     умеренный       -        2018           6
# 21       0.1013     умеренный       -        2018           6
# 23       0.0964     умеренный       -        2018           6
# ...         ...           ...     ...         ...         ...
# 11731    0.0200     умеренное       0        2019          10
# 11732    0.0300     умеренное       0        2019          10
# 11733    0.4500        низкий       0        2019          10
# 11734    0.0934     умеренное       0        2020           5
# 11740    0.7663  95300-216000       -        2019           5
#
# [1220 rows x 12 columns]

# %% [markdown]
# ### Сопоставим с фото

# %%
good_data['reg_num'].unique()
# Out:
# array(['ЛУК-КГ-2020-1', 'ЛУК-КГ-2020-15', 'ЮС-2018-1', ..., 'ПП-2019-4',
#        'ПП-2020-1', 'ТС-2019'], dtype=object)

# %%
years_folders = [yf for yf in os.listdir(data_folder)]

for year in years_folders:
    folders = [f for f in os.listdir(data_folder + year)]
    for each in folders:
        reg_nums = [n for n in os.listdir(data_folder + year + '/' + each)]
    print(reg_nums)

# %%
eopatch = EOPatch.load(data_folder + '2017/2017-01/РН-ННП-2017-67/')

eopatch.timestamp[0].year
eopatch.timestamp[0].month

# %% [markdown]
# ## Работа с фото

# %%
#data_folder = '2017-01/РН-ННП-2017-78/'

#data_folder = '2017-01/РН-ННП-2017-67/'

#data_folder = 'ПП-2020-2/'

# %%
batch_year = '2017'
batch_part = '2017-01'

# %%
folders = [f for f in os.listdir(data_folder) if f.endswith('.csv')]
csv_names = [csv_files[i][:-4] for i in range(len(csv_files))]

for i in range(len(csv_names)):
    dfs[csv_names[i]] = pd.read_csv(PATH + csv_files[i])
    
#Проверим список названий датафреймов в словаре:
dfs.keys()

# %%
years_folders = [f for f in os.listdir(data_folder)]

for year in years_folders:
    folders = [f for f in os.listdir(data_folder + year)]
    
    print(folders)

# %%
eopatch = EOPatch.load(data_folder + '2017/2017-01/РН-ННП-2017-67/')

eopatch

# %%
bands = eopatch.data['L2A']
inds_path = "inds_inference"

for i in range(len(bands)):
    inds = color_scale(bands[i][..., [-3, -2, -1]]).astype("uint8")
    Image.fromarray(inds).save(str(i)+'.png')

# %%
inds = bands[2,:,:,7]*25.5

Image.fromarray(inds).convert("L").save(str(100)+'.png')

# %%
len(eopatch.data['L2A'])

# %%
eopatch.data.keys()

# %%
eopatch[FeatureType.BBOX].get_geojson()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(len(eopatch[FeatureType.TIMESTAMP])):
    ax = fig.add_subplot(5, 4, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.DATA]['L2A'][c,:,:,1:4])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(len(eopatch[FeatureType.TIMESTAMP])):
    ax = fig.add_subplot(5, 4, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.DATA]['L2A'][c,:,:,7]*-1, cmap=plt.get_cmap('Greys')) #NIR
    plt.tight_layout()

# %%
eopatch[FeatureType.DATA]['L2A'][2,:,:,7].min()

# %%
eopatch[FeatureType.DATA]['L2A'][2,:,:,7].max()

# %%
eopatch[FeatureType.DATA]['L2A'][2,:,:,7]

# %%
eopatch[FeatureType.DATA]['L2A'][1,:,:,7]

# %%
eopatch[FeatureType.DATA]['L2A'][2,:,:,7].view()

# %%
eopatch[FeatureType.DATA]['L2A'][1,:,:,7].min()

# %% [markdown]
# CLM (cloud mask) or CLP ().
#
# CLD:
#
# SCL: Scene Classification. .
#
# SNW: Raster mask values range from 0 for high confidence NO snow/ice to 100 for high confidence snow/ice
#
#
# - CLD: **Raster mask**. values range from 0 for high confidence clear sky to 100 for high confidence cloudy
# - CLM: **cloud mask**    CLM: 0 (no clouds), 1 (clouds), 255 (no data)
# - CLP: **cloud probablity** 0–255 (divide by 255 to get to the [0-1] range)
# - IS_DATA:
# - SCL: **scene classification layer**. The meaning of the values is indicated in the Category Names of the band
# - SNW:

# %%
mask_list = ['CLD', 'CLM', 'CLP', 'SCL', 'SNW']

# %%
fig = plt.figure(figsize=(17,20))
for c in range(12):
    ax = fig.add_subplot(6, 6, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.MASK]['CLD'][c,:,:,:])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(12):
    ax = fig.add_subplot(6, 6, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.MASK]['CLM'][c,:,:,:])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(12):
    ax = fig.add_subplot(6, 6, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.MASK]['CLP'][c,:,:,:])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(12):
    ax = fig.add_subplot(6, 6, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.MASK]['SCL'][c,:,:,:])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(17,20))
for c in range(12):
    ax = fig.add_subplot(6, 6, c+1, title=str(eopatch[FeatureType.TIMESTAMP][c]))
    ax.imshow(eopatch[FeatureType.MASK]['SNW'][c,:,:,:])
    plt.tight_layout()
